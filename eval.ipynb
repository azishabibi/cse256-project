# %%
# !pip install --upgrade "evalplus[vllm] @ git+https://github.com/evalplus/evalplus"

# %%
# !pip install transformers accelerate peft evaluate scikit-learn scipy typing_extensions einops deepspeed datasets sentencepiece setuptools rouge-score nltk openai tensorboard tensorboardX bitsandbytes

# %%
# !evalplus.evaluate --model "nahgetout/test" \
                  --dataset humaneval             \
                  --backend hf                         \
                  --greedy
# Out:
# ...
# Greedy decoding ON (--greedy): setting bs=1, n_samples=1, temperature=0
# Initializing a decoder model: nahgetout/test ...
# kwargs = {'device_map': None, 'trust_remote_code': False, 'torch_dtype': torch.bfloat16, 'attn_implementation': 'eager'}
# tokenizer_config.json: 100% 51.1k/51.1k [00:00<00:00, 5.13MB/s]
# tokenizer.json: 100% 17.2M/17.2M [00:00<00:00, 33.7MB/s]
# special_tokens_map.json: 100% 449/449 [00:00<00:00, 2.78MB/s]
# self.eos = ['<|endoftext|>', '<|endofmask|>', '</s>', '\nif __name__', '\ndef main(', '\nprint(', '\n```\n']
# adapter_config.json: 100% 788/788 [00:00<00:00, 6.21MB/s]
# config.json: 100% 1.20k/1.20k [00:00<00:00, 9.72MB/s]
# 2024-11-27 18:54:56.370515: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
# !evalplus.evaluate --model "infly/OpenCoder-8B-Instruct" \
                  --dataset humaneval             \
                  --backend hf                         \
                  --greedy
# Out:
# ...
# Greedy decoding ON (--greedy): setting bs=1, n_samples=1, temperature=0
# Initializing a decoder model: infly/OpenCoder-8B-Instruct ...
# kwargs = {'device_map': None, 'trust_remote_code': False, 'torch_dtype': torch.bfloat16, 'attn_implementation': 'eager'}
# tokenizer_config.json: 100% 9.14k/9.14k [00:00<00:00, 42.5MB/s]
# The repository for infly/OpenCoder-8B-Instruct contains custom code which must be executed to correctly load the model. You can inspect the repository content at https://hf.co/infly/OpenCoder-8B-Instruct.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# tokenization_inflm.py: 100% 10.7k/10.7k [00:00<00:00, 50.2MB/s]
# A new version of the following files was downloaded from https://huggingface.co/infly/OpenCoder-8B-Instruct:
# - tokenization_inflm.py
# ...

# %%
# !evalplus.evaluate --model "infly/OpenCoder-8B-Instruct" \
                  --dataset humaneval             \
                  --backend hf                         \
                  --temperature 0.6   \
# Out:
# Setting batch size to 1
# Initializing a decoder model: infly/OpenCoder-8B-Instruct ...
# kwargs = {'device_map': None, 'trust_remote_code': False, 'torch_dtype': torch.bfloat16, 'attn_implementation': 'eager'}
# The repository for infly/OpenCoder-8B-Instruct contains custom code which must be executed to correctly load the model. You can inspect the repository content at https://hf.co/infly/OpenCoder-8B-Instruct.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# self.eos = ['<|endoftext|>', '<|endofmask|>', '</s>', '\nif __name__', '\ndef main(', '\nprint(', '\n```\n']
# 2024-11-25 05:32:11.879722: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
# !evalplus.evaluate --model "LoftQ/Meta-Llama-3-8B-Instruct-4bit-64rank" \
                  --dataset humaneval             \
                  --backend hf                         \
                  --greedy
# Out:
# ...
# Greedy decoding ON (--greedy): setting bs=1, n_samples=1, temperature=0
# Initializing a decoder model: LoftQ/Meta-Llama-3-8B-Instruct-4bit-64rank ...
# kwargs = {'device_map': None, 'trust_remote_code': False, 'torch_dtype': torch.bfloat16, 'attn_implementation': 'eager'}
# tokenizer_config.json: 100% 51.0k/51.0k [00:00<00:00, 4.52MB/s]
# tokenizer.json: 100% 9.08M/9.08M [00:00<00:00, 33.4MB/s]
# special_tokens_map.json: 100% 301/301 [00:00<00:00, 2.49MB/s]
# self.eos = ['<|endoftext|>', '<|endofmask|>', '</s>', '\nif __name__', '\ndef main(', '\nprint(', '\n```\n']
# config.json: 100% 1.20k/1.20k [00:00<00:00, 9.68MB/s]
# 2024-11-25 00:13:45.099436: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
# !evalplus.evaluate --model "LoftQ/Meta-Llama-3-8B-Instruct-4bit-64rank" \
                  --dataset humaneval             \
                  --backend hf                         \
                  --temperature 0.6   \
# Out:
# Setting batch size to 1
# Initializing a decoder model: LoftQ/Meta-Llama-3-8B-Instruct-4bit-64rank ...
# kwargs = {'device_map': None, 'trust_remote_code': False, 'torch_dtype': torch.bfloat16, 'attn_implementation': 'eager'}
# tokenizer_config.json: 100% 51.0k/51.0k [00:00<00:00, 4.82MB/s]
# tokenizer.json: 100% 9.08M/9.08M [00:00<00:00, 17.5MB/s]
# special_tokens_map.json: 100% 301/301 [00:00<00:00, 2.94MB/s]
# self.eos = ['<|endoftext|>', '<|endofmask|>', '</s>', '\nif __name__', '\ndef main(', '\nprint(', '\n```\n']
# config.json: 100% 1.20k/1.20k [00:00<00:00, 10.2MB/s]
# 2024-11-25 01:18:39.522644: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: fineGrained).
# The token `mine` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# ...

# %%
# !evalplus.evaluate --model "meta-llama/Meta-Llama-3-8B-Instruct" \
                  --dataset humaneval             \
                  --backend hf                         \
                  --greedy
# Out:
# Greedy decoding ON (--greedy): setting bs=1, n_samples=1, temperature=0
# Initializing a decoder model: meta-llama/Meta-Llama-3-8B-Instruct ...
# kwargs = {'device_map': None, 'trust_remote_code': False, 'torch_dtype': torch.bfloat16, 'attn_implementation': 'eager'}
# tokenizer_config.json: 100% 51.0k/51.0k [00:00<00:00, 5.23MB/s]
# tokenizer.json: 100% 9.09M/9.09M [00:00<00:00, 15.7MB/s]
# special_tokens_map.json: 100% 73.0/73.0 [00:00<00:00, 694kB/s]
# self.eos = ['<|endoftext|>', '<|endofmask|>', '</s>', '\nif __name__', '\ndef main(', '\nprint(', '\n```\n']
# config.json: 100% 654/654 [00:00<00:00, 5.28MB/s]
# 2024-11-25 01:40:21.962957: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
# !evalplus.evaluate --model "meta-llama/Meta-Llama-3-8B-Instruct" \
                  --dataset humaneval             \
                  --backend hf                         \
                  --temperature 0.6
# Out:
# Setting batch size to 1
# Initializing a decoder model: meta-llama/Meta-Llama-3-8B-Instruct ...
# kwargs = {'device_map': None, 'trust_remote_code': False, 'torch_dtype': torch.bfloat16, 'attn_implementation': 'eager'}
# self.eos = ['<|endoftext|>', '<|endofmask|>', '</s>', '\nif __name__', '\ndef main(', '\nprint(', '\n```\n']
# 2024-11-25 01:57:01.713276: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-25 01:57:01.732419: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
